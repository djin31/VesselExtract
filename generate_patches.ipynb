# %%
import numpy as np
from skimage import io
from skimage import color
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_dir = "DRIVE/training/"
image_list = os.listdir("DRIVE/training/images/")
image_list
# Out:
# ['40_training.tif',
#  '33_training.tif',
#  '30_training.tif',
#  '34_training.tif',
#  '25_training.tif',
#  '32_training.tif',
#  '22_training.tif',
#  '26_training.tif',
#  '23_training.tif',
#  '31_training.tif',
#  '36_training.tif',
#  '29_training.tif',
#  '28_training.tif',
#  '38_training.tif',
#  '27_training.tif',
#  '21_training.tif',
#  '39_training.tif',
#  '24_training.tif',
#  '37_training.tif',
#  '35_training.tif']

# %%
def random_patch(image,manual,mask,count):
    x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    while (mask[x][y]<0.001 and mask[x][y+256]<0.001 and mask[x+256][y]<0.001 and mask[x+256][y+256]<0.001):
        x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    t_im = image[x:x+256,y:y+256]
    io.imsave("training/"+str(count)+".jpg",t_im)
    t_im = manual[x:x+256,y:y+256]
    io.imsave("manual/"+str(count)+".jpg",t_im)

# %%
count=0
for image in image_list:
    im = io.imread(image_dir+"images/"+image)
    mask = io.imread(image_dir+"mask/"+image[0:2]+"_training_mask.gif")
    manual = io.imread(image_dir+"1st_manual/"+image[0:2]+"_manual1.gif")
    for i in range(100):
        random_patch(im,manual,mask,count)
        count+=1
# Out:
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/210.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/221.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/224.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/242.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/243.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/262.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/263.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/268.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/269.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/273.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/298.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/723.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/727.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/743.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/745.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/785.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/789.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
im_number = str(np.random.randint(0,1000))
im = io.imread("training/" + im_number + ".jpg")
vessel = io.imread("manual/"+ im_number + ".jpg")
f = plt.figure()
f.add_subplot(1,2, 1)
plt.imshow(im)
f.add_subplot(1,2,2)
io.imshow(vessel)

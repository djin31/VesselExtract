# %%
import numpy as np
from skimage import io
from skimage import color
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_dir = "DRIVE/training/"
image_list = os.listdir("DRIVE/training/images/")
image_list
# Out:
# ['29_training.tif',
#  '36_training.tif',
#  '35_training.tif',
#  '25_training.tif',
#  '34_training.tif',
#  '32_training.tif',
#  '22_training.tif',
#  '21_training.tif',
#  '38_training.tif',
#  '23_training.tif',
#  '26_training.tif',
#  '31_training.tif',
#  '33_training.tif',
#  '24_training.tif',
#  '40_training.tif',
#  '27_training.tif',
#  '39_training.tif',
#  '28_training.tif',
#  '37_training.tif',
#  '30_training.tif']

# %%
def random_patch(image,manual,mask,count):
    # patch without any effects
    x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    while (mask[x][y]<0.001 and mask[x][y+256]<0.001 and mask[x+256][y]<0.001 and mask[x+256][y+256]<0.001):
        x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    t_im = image[x:x+256,y:y+256]
    io.imsave("training/"+str(count)+"_orig.jpg",t_im)
    t_im = manual[x:x+256,y:y+256]
    io.imsave("manual/"+str(count)+"_orig.jpg",t_im)
    
    # flipped image
    x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    while (mask[x][y]<0.001 and mask[x][y+256]<0.001 and mask[x+256][y]<0.001 and mask[x+256][y+256]<0.001):
        x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    t_im = np.flip(image[x:x+256,y:y+256],axis=(0,1))
    io.imsave("training/"+str(count)+"_flip.jpg",t_im)
    t_im = manual[x:x+256,y:y+256]
    io.imsave("manual/"+str(count)+"_flip.jpg",t_im)
    
    # noise addition
    x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    while (mask[x][y]<0.001 and mask[x][y+256]<0.001 and mask[x+256][y]<0.001 and mask[x+256][y+256]<0.001):
        x,y = np.random.randint(0,im.shape[0]-256),np.random.randint(0,im.shape[1]-256)
    t_im = np.clip(image[x:x+256,y:y+256] + np.random.randint(20,size=(256,256,3)), 0 , 255)
    io.imsave("training/"+str(count)+"_noise.jpg",t_im)
    t_im = manual[x:x+256,y:y+256]
    io.imsave("manual/"+str(count)+"_noise.jpg",t_im)

# %%
# !mkdir -p training
# !mkdir -p manual
count=0
for image in image_list:
    im = io.imread(image_dir+"images/"+image)
    mask = io.imread(image_dir+"mask/"+image[0:2]+"_training_mask.gif")
    manual = io.imread(image_dir+"1st_manual/"+image[0:2]+"_manual1.gif")
    for i in range(50):
        random_patch(im,manual,mask,count)
        count+=1
# Out:
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:130: UserWarning: Possible precision loss when converting from int64 to float64
#   .format(dtypeobj_in, dtypeobj_out))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/0_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:126: UserWarning: Possible sign loss when converting negative image of type int64 to positive image of type uint8.
#   .format(dtypeobj_in, dtypeobj_out))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 255 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/1_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 230 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/2_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 244 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/3_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 254 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/4_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/5_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/6_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/7_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/8_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/9_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/10_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 252 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/11_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/12_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 239 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/13_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/14_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/15_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/16_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/17_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/18_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/19_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/20_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/21_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 231 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/22_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/23_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/24_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/25_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/26_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 236 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/27_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/28_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 228 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/29_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/30_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/31_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/32_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/util/dtype.py:179: UserWarning: Downcasting int64 to uint8 without scaling because max value 249 fits in uint8
#   "value {} fits in {}".format(a.dtype, dtype, a.max(), dtype))
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/33_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/34_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/35_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/36_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/37_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/38_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/39_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/40_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/41_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/42_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training/43_noise.jpg is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /home/chironx/anaconda3/lib/python3.7/site-packages/skimage/io/_io.py:140: UserWarning: training